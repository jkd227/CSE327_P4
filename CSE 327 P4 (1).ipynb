# %% [markdown]
# The block below imports a necessary module and checks if you are in the right directory. If you do not see a list of python files when you run the block, please make sure you have uploaded the zip file and unzipped it.

# %%
import matplotlib.pyplot as plt

# %pwd
# %ls
# Out:
#  atomgenerator.py    embedmodel.py       kbencoder.py          nnunifier.py
#  autoencoder.py      evaluate.py         kbparser.py           reasoner.py
#  basictypes.py       gameofthrones.txt   knowledgebase.py      termwalk.py
#  chainbased.py       gen_queries.py      mr_back_reasoner.py   vocab.py
# 'CSE 327 P4.ipynb'   helpers/            nnreasoner.py

# %% [markdown]
# If you want to create a random knowledge base, run the following code.
#
# Creates the files:
#
# * randomKB.txt - A random KB generated using 10 predicates and 100 constants.
# * vocab.pkl - Indexes the full set of predicates, constants and variables used by the knowledge base.

# %%
# !python kbencoder.py --generate_kb --new_vocab --save_vocab
# !head randomKB.txt
# Out:
# Classes: 1000000000.0
# Max arity: 4
# KB generated (150)
# p3(a40, a79).
# p7(a93, a47).
# p4(a12).
# p4(a10).
# p3(a62, a6).
# p9(a32, a0).
# p5(a5).
# p8(a99, a69, a27, a21).
# p2(a13, a30).
# p0(a51, a54, a21).

# %% [markdown]
# The following code prepares an existing knowledge base (KB) for use. To use a KB of your choosing, replace gameofthrones.txt with the file name of any KB you want to use.
#
# Creates the file:
#
# *   vocab.pkl - Indexes the full set of predicates, constants and variables used by the knowledge base.

# %%
# !python kbencoder.py --kb_path gameofthrones.txt --vocab_from_kb --save_vocab
# Out:
# Creating vocabulary from last gameofthrones.txt knowledge base

# %% [markdown]
# Train a neural net to convert first-order logic atoms into meaningful numeric vectors. We call these vectors "embeddings," and the learned model the embedding model. The code creates random atoms and then uses a mechanism known as triplet loss to place unifying atoms closer together.
#
# Creates the files:
#
# *   rKB_model.pth - Saves the learned weights for the embedding model
# *   training_loss-45-106-2-50.png - A plot of the training loss after each epoch. This file's name depends on the vocabulary of your KB: the four numbers are number of predicates, number of constants, max arity of the predicates, and the embedding size used. If you changed the KB, you'll need to look up the name in your drive and update the code block that displays this file.

# %%
# !python kbencoder.py --kb_path gameofthrones.txt --train_unification_model
# Out:
# Using cuda device
# Uni model embed size: 50
#  [████████████████████] 3500/3500 Anchors generated
#  [████████████████████] 70000/70000 Triplets generated
#  [█████---------------] 18104/70000 Triplet encodings
# IOPub data rate exceeded.
# The Jupyter server will temporarily stop sending output
# to the client in order to avoid crashing it.
# To change this limit, set the config variable
# `--ServerApp.iopub_data_rate_limit`.
#
# Current values:
# ServerApp.iopub_data_rate_limit=1000000.0 (bytes/sec)
# ServerApp.rate_limit_window=3.0 (secs)
#  [█████████████-------] 48277/70000 Triplet encodings
# IOPub data rate exceeded.
# The Jupyter server will temporarily stop sending output
# to the client in order to avoid crashing it.
# To change this limit, set the config variable
# `--ServerApp.iopub_data_rate_limit`.
#
# Current values:
# ServerApp.iopub_data_rate_limit=1000000.0 (bytes/sec)
# ServerApp.rate_limit_window=3.0 (secs)
#  [████████████████████] 70000/70000 Triplet encodings
# Early stopping triggered-------------] 33.1% Epoch | [Epoch 166/500, Training Loss: 0.0629, Validation Loss: 0.2583]
# Saved model.
# Saved plot.
# unification model generated

# %%
img = plt.imread('training_loss-45-106-2-50.png')
plt. imshow(img)

# %% [markdown]
# Generate a set of train and test queries from your knowledge base. This will also generate the deductive closure (all facts that can be inferred) of your KB using forward-chaining.
#
# Produces the files:
#
# *  all_facts.txt - A list of all facts that can be inferred from the KB. This is used to generate queries that are guaranteed to have an answer.
# *  train_queries.txt - A set of training queries where each will have at least one answer.
# *  test_queries.txt - A set of test queries where each will have at least one answer.

# %%
# !python kbencoder.py --kb_path gameofthrones.txt -g
# Out:
# Generating facts list...
# Forward chaining depth: 1
# New facts: 442
# Forward chaining depth: 2
# New facts: 175
# Forward chaining depth: 3
# New facts: 82
# Forward chaining depth: 4
# New facts: 12
# Forward chaining depth: 5
# New facts: 1
# Forward chaining depth: 6
# New facts: 2
# Forward chaining depth: 7
#
# Facts list generated
# 714 total facts. Max depth = 6
#
# Number of queries: 200
# 100 training queries generated
# 100 testing queries generated

# %% [markdown]
# Create a training set for the scoring model. The examples will consist of goal, rule, score pairs, where a score of 1 means the rule can solve the goal, and 0 means it cannot. It runs the full set of training queries with a randomized backward-chaining process. This step can sometimes take a long time and is not able to take advantage of a GPU (with the gameofthrones KB it took ~45 minutes).
#
# Creates a file:
# *  mr_train_examples.csv - Contains a line for each goal/rule/score example.

# %%
# !python kbencoder.py --kb_path gameofthrones.txt -p
# Out:
# running training queries...
# Negative facts will be generated
# 1: [child(_EX2, rhaegar_targaryen)]
# min depth: 2
# Nodes: 5
# Answers: 3
#
# 2: [father(_EX6, aegon_targaryen)]
# min depth: 3
# Nodes: 5
# Answers: 1
#
# 3: [descendant(robert_baratheon, X), parent(X, Y), father(steffon_baratheon, Y), mother(X, Y)]
# min depth: 3
# Nodes: 500
# Answers: 2
#
# 4: [who_killed_daenerys(_EX4)]
# min depth: 2
# Nodes: 3
# Answers: 1
#
# 5: [child(loras_tyrell, _EX4)]
# min depth: 2
# Nodes: 4
# Answers: 2
#
# 6: [parent(X, Y), mother(X, sansa_stark), descendant(sansa_stark, X), parent(eddard_stark, Y), daughter(Y, X)]
# min depth: 1
# Nodes: 105
# Answers: 104
#
# 7: [father(Z, _EX1)]
# min depth: 3
# Nodes: 160
# Answers: 54
#
# 8: [son(X, Y), descendant(tyrion_lannister, X), descendant(joffery_lannister, X), descendant(joffery_lannister, Y)]
# min depth: 3
# Nodes: 178
# Answers: 72
#
# 9: [ancestor(_EX4, _EX5)]
# min depth: 2
# Nodes: 23487
# Answers: 230
#
# 10: [son(Y, _EX3)]
# min depth: 3
# Nodes: 121
# Answers: 72
#
# 11: [ancestor(X, Y), ancestor(X, Z), son(Y, X), love(jorah_mormont, Z)]
# min depth: 2
# Nodes: 100171
# Answers: 128
#
# 12: [son(X, aegon_v_targaryen), ancestor(X, Y), parent(rhaella_targaryen, Y)]
# min depth: 3
# Nodes: 52
# Answers: 3
#
# 13: [ancestor(unknown_mother_greyjoy, X), son(X, Y), descendant(rodrick_greyjoy, Y)]
# min depth: 2
# Nodes: 21562
# Answers: 5
#
# 14: [descendant(_EX0, _EX5)]
# min depth: 3
# Nodes: 41293
# Answers: 225
#
# 15: [child(obara_sand, X), father(lewyn_martell, X)]
# min depth: 2
# Nodes: 4
# Answers: 2
#
# 16: [descendant(rhaenys_targaryen, Y)]
# min depth: 3
# Nodes: 15253
# Answers: 26
#
# 17: [ancestor(Y, X), ancestor(unknown_father_greyjoy, X), ancestor(Y, theon_greyjoy), son(theon_greyjoy, Y)]
# min depth: 4
# Nodes: 23649
# Answers: 210
#
# 18: [ancestor(X, _EX2)]
# min depth: 4
# Nodes: 25268
# Answers: 214
#
# 19: [ancestor(unknown_mother_lannister, _EX3)]
# Restart...
# min depth: 6
# min depth: 4
# Nodes: 44592
# Answers: 11
#
# 20: [descendant(_EX6, _EX3)]
# min depth: 3
# Nodes: 26609
# Answers: 184
#
# 21: [ancestor(unknown_mother_martell, _EX5)]
# Restart...
# min depth: 4
# Nodes: 57942
# Answers: 20
#
# 22: [descendant(tommen_lannister, X), ancestor(X, joffery_lannister)]
# min depth: 3
# Nodes: 77
# Answers: 16
#
# 23: [descendant(_EX5, X)]
# min depth: 5
# Nodes: 47650
# Answers: 219
#
# 24: [descendant(X, Y), descendant(X, olenna_tyrell), child(X, Y), ancestor(Y, X), ancestor(Y, loras_tyrell)]
# min depth: 5
# Nodes: 11413
# Answers: 196
#
# 25: [descendant(Y, X), ancestor(X, yara_greyjoy), parent(Z, Y), descendant(_EX0, Z), daughter(yara_greyjoy, _EX0)]
# min depth: 5
# Nodes: 10478
# Answers: 182
#
# 26: [ancestor(Z, X)]
# min depth: 4
# Nodes: 1575
# Answers: 190
#
# 27: [child(_EX6, oberyn_martell)]
# min depth: 2
# Nodes: 7
# Answers: 5
#
# 28: [father(_EX5, _EX6)]
# min depth: 3
# Nodes: 103
# Answers: 54
#
# 29: [ancestor(_EX5, _EX1)]
# min depth: 2
# Nodes: 39759
# Answers: 238
#
# 30: [status(night_king, X), status(Y, X), son(Y, aegon_v_targaryen)]
# min depth: 1
# Nodes: 2
# Answers: 1
#
# 31: [descendant(X, Y), parent(steffon_baratheon, X), child(shireen_baratheon, X), ancestor(Y, shireen_baratheon)]
# Restart...
# min depth: 3
# Nodes: 18322
# Answers: 210
#
# 32: [female(X)]
# min depth: 1
# Nodes: 33
# Answers: 32
#
# 33: [status(Y, X), status(daeron_targaryen, X)]
# min depth: 1
# Nodes: 80
# Answers: 79
#
# 34: [child(X, rickard_stark), descendant(X, rickard_stark), parent(X, Y), ancestor(unknown_mother_stark, Y), parent(unknown_mother_stark, X)]
# min depth: 2
# Nodes: 6
# Answers: 4
#
# 35: [child(tyrion_lannister, tywin_lannister)]
# min depth: 2
# Nodes: 3
# Answers: 1
#
# 36: [descendant(X, unknown_mother_targaryen), descendant(Y, X), ancestor(X, viserys_targaryen), ancestor(Y, rhaenys_targaryen), descendant(aegon_targaryen, Y)]
# min depth: 3
# Nodes: 20548
# Answers: 14
#
# 37: [ancestor(Y, X), status(X, dead), son(X, Y), ancestor(olenna_tyrell, X)]
# Restart...
# min depth: 2
# Nodes: 100195
# Answers: 106
#
# 38: [ancestor(X, rickon_stark), son(Y, X), descendant(Y, X), parent(unknown_mother_stark, Y)]
# Restart...
# min depth: 4
# Nodes: 3952
# Answers: 4
#
# 39: [ancestor(X, Y), parent(X, Y), father(X, Y), parent(cassana_estermont, X)]
# min depth: 2
# Nodes: 43442
# Answers: 198
#
# 40: [ancestor(_EX3, X)]
# Restart...
# min depth: 2
# Nodes: 1449
# Answers: 188
#
# 41: [ancestor(X, daeron_targaryen), ancestor(X, viserys_targaryen), descendant(viserys_targaryen, X)]
# min depth: 2
# Nodes: 100130
# Answers: 2
#
# 42: [status(thoros_of_myr, X), status(aerys_targaryen, X), status(nymeria_sand, X), status(Y, X), ancestor(joanna_lannister, Y)]
# min depth: 1
# Nodes: 2
# Answers: 1
#
# 43: [father(Z, _EX1)]
# min depth: 3
# Nodes: 160
# Answers: 54
#
# 44: [father(X, nymeria_sand), child(obara_sand, X)]
# min depth: 3
# Nodes: 5
# Answers: 1
#
# 45: [kill(X, Y), kill(arya_stark, X), status(Y, alive), creatures(Y)]
# min depth: 1
# Nodes: 8
# Answers: 7
#
# 46: [who_betrayed_daenerys(_EX0)]
# min depth: 2
# Nodes: 7
# Answers: 5
#
# 47: [son(_EX4, Z)]
# min depth: 3
# Nodes: 121
# Answers: 72
#
# 48: [son(daeron_targaryen, _EX2)]
# min depth: 3
# Nodes: 5
# Answers: 2
#
# 49: [father(X, _EX5)]
# min depth: 3
# Nodes: 160
# Answers: 54
#
# 50: [descendant(_EX1, kevan_lannister)]
# Restart...
# min depth: 3
# Nodes: 13
# Answers: 3
#
# 51: [child(sarella_sand, _EX4)]
# min depth: 2
# Nodes: 4
# Answers: 2
#
# 52: [love(Y, X), who_loved_daenerys_and_was_corresponded(X), daughter(Y, aerys_targaryen), love(X, Y), who_loved_daenerys(X)]
# min depth: 1
# Nodes: 12
# Answers: 11
#
# 53: [ancestor(Y, joffery_lannister)]
# Restart...
# min depth: 4
# Nodes: 26027
# Answers: 28
#
# 54: [child(_EX4, oberyn_martell)]
# min depth: 2
# Nodes: 7
# Answers: 5
#
# 55: [descendant(aerys_targaryen, X), father(X, duncan_targaryen)]
# min depth: 3
# Nodes: 4448
# Answers: 2
#
# 56: [son(X, doran_martell), ancestor(Y, X), son(X, Y), ancestor(unknown_mother_martell, X)]
# min depth: 3
# Nodes: 50
# Answers: 1
#
# 57: [child(_EX5, _EX2)]
# min depth: 2
# Nodes: 106
# Answers: 104
#
# 58: [daughter(cersei_lannister, _EX1)]
# min depth: 3
# Nodes: 6
# Answers: 2
#
# 59: [mother(Y, X), ancestor(stannis_baratheon, X), child(X, Y)]
# min depth: 3
# Nodes: 83
# Answers: 49
#
# 60: [child(_EX2, _EX6)]
# min depth: 2
# Nodes: 106
# Answers: 104
#
# 61: [parent(X, yara_greyjoy), parent(X, theon_greyjoy)]
# min depth: 1
# Nodes: 3
# Answers: 2
#
# 62: [son(X, doran_martell), child(X, mellario_of_norvos), ancestor(lewyn_martell, X)]
# min depth: 3
# Nodes: 50
# Answers: 1
#
# 63: [parent(unknown_mother_targaryen, X), ancestor(unknown_mother_targaryen, X)]
# min depth: 1
# Nodes: 5
# Answers: 4
#
# 64: [ancestor(tytos_lannister, X), ancestor(X, tyrion_lannister)]
# min depth: 2
# Nodes: 43487
# Answers: 12
#
# 65: [kill(X, Y), love(X, khal_drogo), who_betrayed_daenerys(Y)]
# min depth: 1
# Nodes: 8
# Answers: 7
#
# 66: [descendant(nymeria_sand, X), ancestor(X, oberyn_martell)]
# min depth: 3
# Nodes: 517
# Answers: 4
#
# 67: [ancestor(X, Y), parent(X, Z), parent(X, Y), status(Z, dead)]
# Restart...
# min depth: 2
# Nodes: 100107
# Answers: 127
#
# 68: [child(X, cassana_estermont)]
# min depth: 2
# Nodes: 5
# Answers: 3
#
# 69: [descendant(X, _EX3)]
# Restart...
# Restart...
# min depth: 3
# Nodes: 23060
# Answers: 168
#
# 70: [descendant(Z, lewyn_martell)]
# min depth: 3
# Nodes: 2305
# Answers: 5
#
# 71: [ancestor(_EX3, sarella_sand)]
# min depth: 2
# Nodes: 15321
# Answers: 2
#
# 72: [ancestor(unknown_mother_targaryen, X), ancestor(X, jon_snow), descendant(rhaenys_targaryen, X)]
# min depth: 4
# Nodes: 13924
# Answers: 17
#
# 73: [daughter(_EX0, _EX4)]
# min depth: 3
# Nodes: 62
# Answers: 28
#
# 74: [descendant(X, unknown_mother_martell), daughter(X, Y), son(Y, Z), descendant(X, Z), daughter(obara_sand, Y)]
# min depth: 5
# Nodes: 2448
# Answers: 7
#
# 75: [descendant(X, steffon_baratheon), parent(Y, X), parent(cassana_estermont, Y)]
# Restart...
# Restart...
# min depth: 5
# Nodes: 1316
# Answers: 7
#
# 76: [mother(unknown_mother_stark, _EX3)]
# min depth: 3
# Nodes: 10
# Answers: 4
#
# 77: [child(rhaella_targaryen, Y)]
# min depth: 2
# Nodes: 4
# Answers: 2
#
# 78: [love(X, Y), who_loved_daenerys(X), betray(viserys_targaryen, Y), love(hizdahr_zo_loraq, Y)]
# min depth: 1
# Nodes: 12
# Answers: 11
#
# 79: [daughter(X, Y), descendant(rhaegar_targaryen, X), ancestor(X, Z), parent(Y, duncan_targaryen), ancestor(Y, Z)]
# min depth: 3
# Nodes: 134
# Answers: 28
#
# 80: [status(X, alive), ancestor(Y, X), ancestor(Z, Y), male(Y), descendant(renly_baratheon, Z)]
# min depth: 1
# Nodes: 17
# Answers: 16
#
# 81: [son(_EX3, _EX2)]
# min depth: 3
# Nodes: 178
# Answers: 72
#
# 82: [descendant(_EX0, tytos_lannister)]
# min depth: 3
# Nodes: 1980
# Answers: 11
#
# 83: [status(willem_lannister, X), status(Y, X), mother(unknown_mother_targaryen, Y)]
# min depth: 1
# Nodes: 2
# Answers: 1
#
# 84: [descendant(Z, _EX5)]
# min depth: 3
# Nodes: 42086
# Answers: 205
#
# 85: [descendant(martyn_lannister, Y)]
# Restart...
# min depth: 3
# Nodes: 32810
# Answers: 1
#
# 86: [daughter(Y, aerys_targaryen)]
# min depth: 3
# Nodes: 35
# Answers: 1
#
# 87: [ancestor(_EX5, jaime_lannister)]
# min depth: 2
# Nodes: 486
# Answers: 2
#
# 88: [descendant(rhaella_targaryen, X), parent(X, rhaella_targaryen)]
# Restart...
# Restart...
# min depth: 3
# Nodes: 24632
# Answers: 2
#
# 89: [who_betrayed_daenerys(_EX1)]
# min depth: 2
# Nodes: 7
# Answers: 5
#
# 90: [descendant(_EX6, alannys_harlaw)]
# Restart...
# min depth: 3
# Nodes: 2647
# Answers: 4
#
# 91: [son(_EX6, _EX1)]
# min depth: 3
# Nodes: 178
# Answers: 72
#
# 92: [ancestor(_EX1, _EX5)]
# min depth: 2
# Nodes: 100115
# Answers: 142
#
# 93: [son(X, Y), parent(Y, X), descendant(margaery_tyrell, Y)]
# min depth: 3
# Nodes: 121
# Answers: 72
#
# 94: [descendant(X, Z), child(Y, X), descendant(Y, mellario_of_norvos), parent(Z, ella_martell)]
# min depth: 3
# Nodes: 42356
# Answers: 153
#
# 95: [ancestor(X, Y), daughter(Y, X), female(Y)]
# min depth: 2
# Nodes: 1546
# Answers: 198
#
# 96: [child(benjen_stark, X), ancestor(X, Y), descendant(bran_stark, Y)]
# min depth: 2
# Nodes: 4
# Answers: 2
#
# 97: [descendant(sarella_sand, _EX4)]
# Restart...
# Restart...
# min depth: 3
# Nodes: 28315
# Answers: 3
#
# 98: [mother(Y, benjen_stark)]
# min depth: 3
# Nodes: 5
# Answers: 1
#
# 99: [ancestor(_EX0, joffery_lannister)]
# min depth: 2
# Nodes: 100166
# Answers: 8
#
# 100: [ancestor(Z, _EX1)]
# min depth: 2
# Nodes: 24882
# Answers: 246
#
# Before removing duplicates: 1310606 examples
# After removing duplicates: 21455 examples
# Replicating pos examples 3 times
# pos len=17305, neg len=17305

# %% [markdown]
# Train the scoring model. This step will usually take several minutes, especially if you are not using a GPU (for the gameofthrones KB, it takes about 30 minutes on CPU).
#
# Creates a file:
# * uni_mr_model.pt - Contains the weights for the learned scoring model

# %%
# !python nnreasoner.py --embed_type unification
# Out:
# States from vocab: vocab
# Num predicates: 45
# Max arity: 2
# Num constants: 106
# Num variables: 10
#
# Training unification
# Embed size: 50
# Reading examples from mr_train_examples.csv
# Parsing examples...
# Generating embeddings...
# Embedding input size: 277
#  [███████████████] 34609/34609 Prepping examples
# Loaded data...
# Using cuda device
# /opt/tljh/user/envs/cse327python311/lib/python3.11/site-packages/torch/nn/modules/lazy.py:180: UserWarning: Lazy modules are a new feature under heavy development so changes to the API or functionality can happen at any moment.
#   warnings.warn('Lazy modules are a new feature under heavy development '
# 0	0.61385 (-)
# 50	0.31681 (-0.0061)
# 100	0.27049 (-0.0036)
# 150	0.24313 (-0.0026)
# 200	0.22897 (-0.0020)
# 250	0.21627 (-0.0017)
# 300	0.20388 (-0.0014)
# 350	0.19261 (-0.0013)
# 400	0.18442 (-0.0011)
# 450	0.18001 (-0.0010)
# 500	0.17603 (-0.0009)
# 550	0.16999 (-0.0008)
# 600	0.16517 (-0.0008)
# 650	0.16248 (-0.0007)
# 700	0.16121 (-0.0006)
# 750	0.15829 (-0.0006)
# 800	0.15367 (-0.0006)
# 850	0.15261 (-0.0005)
# 900	0.15277 (-0.0005)
# 950	0.15092 (-0.0005)
# 1000	0.14815 (-0.0005)
# 1050	0.14684 (-0.0004)
# 1100	0.14726 (-0.0004)
# 1150	0.14460 (-0.0004)
# 1200	0.14280 (-0.0004)
# 1250	0.14234 (-0.0004)
# 1300	0.14264 (-0.0003)
# 1350	0.13991 (-0.0003)
# 1400	0.13861 (-0.0003)
# 1450	0.14086 (-0.0003)
# 1500	0.13797 (-0.0003)
# 1550	0.13569 (-0.0003)
# 1600	0.13513 (-0.0003)
# 1650	0.13353 (-0.0003)
# 1700	0.13339 (-0.0003)
# 1750	0.13432 (-0.0002)
# 1800	0.13186 (-0.0002)
# 1850	0.13361 (-0.0002)
# 1900	0.13055 (-0.0002)
# 1950	0.13220 (-0.0002)
# 2000	0.13164 (-0.0002)
# 2050	0.12945 (-0.0002)
# 2100	0.13042 (-0.0002)
# 2150	0.12909 (-0.0002)
# 2200	0.13022 (-0.0002)
# 2250	0.12955 (-0.0002)
# 2300	0.12668 (-0.0002)
# 2350	0.12733 (-0.0002)
# 2400	0.12563 (-0.0002)
# 2450	0.12704 (-0.0002)
# 2500	0.12562 (-0.0002)
# 2550	0.12448 (-0.0002)
# 2600	0.12562 (-0.0002)
# 2650	0.12436 (-0.0002)
# 2700	0.12359 (-0.0001)
# 2750	0.12417 (-0.0001)
# 2800	0.12196 (-0.0001)
# 2850	0.12249 (-0.0001)
# 2900	0.12341 (-0.0001)
# 2950	0.12289 (-0.0001)
# 3000	0.12142 (-0.0001)
# 3050	0.12086 (-0.0001)
# 3100	0.12212 (-0.0001)
# 3149	0.12075 (-0.0001)
# Saved training loss figure.

# %%
img = plt.imread('guided_loss-unification45-106-2-50.png')
plt. imshow(img)
# Out:
# ---------------------------------------------------------------------------
# NameError                                 Traceback (most recent call last)
# Cell In[4], line 1
# ----> 1 img = plt.imread('guided_loss-unification45-106-2-50.png')
#       2 plt. imshow(img)
#
# NameError: name 'plt' is not defined

# %% [markdown]
# Evaluate the scoring model by running evaluate.py. We compare the standard backward-chaining algorithm (-s) with the one that uses our learned scoring model (-u).
#
# The output lists each query, and then provides a line that gives information about query execution. These are: number of nodes explored in the tree, depth of the solution, execution time in seconds, and the speed of exploring the tree (nodes per second).
#
# The names of the files produced depend on the KB used and the options selected. The code below produces the files:
#
# * std-45-106-2-50.csv - A CSV file with query results for the standard backward-chaining algorithm
# * ming-45-106-2-50.csv - A CSV file with query results for the learned reasoner. ming stands for "min scoring goal" and is the default strategy for deciding how to make use of the scores
#
# If you use a different knowledge base, you will likely get different file names that depend on the features of that KB's vocabulary.

# %%
# !python evaluate.py --kb gameofthrones.txt -s
# !python evaluate.py --kb gameofthrones.txt -u
# Out:
# using cuda device
# STANDARD
#
# Query 1: [mother(X, kevan_lannister), parent(X, tywin_lannister)]
# 32 :: 4 - 00:00:00 (1592 nps)
#
# Query 2: [male(X), kill(arya_stark, X), night_walkers_king(X), who_brought_the_winter(X), night_walker(X)]
# 33 :: 7 - 00:00:00 (16703 nps)
#
# Query 3: [ancestor(Z, _EX1)]
# 3 :: 2 - 00:00:00 (1962 nps)
#
# Query 4: [ancestor(lewyn_martell, _EX5)]
# 3 :: 2 - 00:00:00 (3073 nps)
#
# Query 5: [descendant(X, _EX6)]
# 4 :: 3 - 00:00:00 (3333 nps)
#
# Query 6: [descendant(_EX5, _EX6)]
# 4 :: 3 - 00:00:00 (3312 nps)
#
# Query 7: [father(_EX2, maron_greyjoy)]
# 8 :: 3 - 00:00:00 (2171 nps)
#
# Query 8: [child(X, rhaella_targaryen), descendant(X, rhaella_targaryen), descendant(X, Y), descendant(rhaella_targaryen, Y)]
# 59 :: 13 - 00:00:00 (3401 nps)
#
# Query 9: [parent(elia_martell, X), male(X), child(X, elia_martell), ancestor(rhaegar_targaryen, X)]
# 7 :: 6 - 00:00:00 (2731 nps)
#
# Query 10: [mother_dragons(daenerys_targaryen, X), status(X, Y), status(sansa_stark, Y), kill(night_king, X)]
# 8 :: 4 - 00:00:00 (3263 nps)
#
# Query 11: [descendant(_EX0, Y)]
# 4 :: 3 - 00:00:00 (3286 nps)
#
# Query 12: [ancestor(cassana_estermont, _EX4)]
# 3 :: 2 - 00:00:00 (3145 nps)
#
# Query 13: [descendant(lancel_lannister, Z)]
# 4 :: 3 - 00:00:00 (5128 nps)
#
# Query 14: [ancestor(_EX1, jon_snow)]
# 3 :: 2 - 00:00:00 (3770 nps)
#
# Query 15: [male(X), child(X, Y), son(X, unknown_mother_targaryen), parent(Y, aerys_targaryen)]
# 26 :: 7 - 00:00:00 (189 nps)
#
# Query 16: [ancestor(_EX0, tommen_lannister)]
# 3 :: 2 - 00:00:00 (3696 nps)
#
# Query 17: [ancestor(_EX0, lyanna_stark)]
# 3 :: 2 - 00:00:00 (4084 nps)
#
# Query 18: [daughter(_EX2, _EX3)]
# 6 :: 3 - 00:00:00 (2570 nps)
#
# Query 19: [child(rhaella_targaryen, _EX2)]
# 3 :: 2 - 00:00:00 (3931 nps)
#
# Query 20: [rightful_heir_iron_throne_descedant_from_last_king_or_queen(_EX5)]
# 8 :: 3 - 00:00:00 (1905 nps)
#
# Query 21: [parent(Y, X), descendant(sansa_stark, X), ancestor(Y, rickon_stark)]
# 78 :: 8 - 00:00:00 (1966 nps)
#
# Query 22: [descendant(jaime_lannister, _EX6)]
# 4 :: 3 - 00:00:00 (5180 nps)
#
# Query 23: [descendant(_EX4, Y)]
# 4 :: 3 - 00:00:00 (2453 nps)
#
# Query 24: [status(X, Z), father(Y, X), child(X, Y), status(lewyn_martell, Z), ancestor(Y, X)]
# 38 :: 9 - 00:00:00 (1435 nps)
#
# Query 25: [daughter(sansa_stark, _EX1)]
# 4 :: 3 - 00:00:00 (4239 nps)
#
# Query 26: [ancestor(_EX6, _EX3)]
# 3 :: 2 - 00:00:00 (2633 nps)
#
# Query 27: [descendant(_EX6, X)]
# 4 :: 3 - 00:00:00 (3134 nps)
#
# Query 28: [descendant(jon_snow, X)]
# 4 :: 3 - 00:00:00 (5350 nps)
#
# Query 29: [descendant(Y, X), mother(X, Z), male(Y), child(Z, unknown_father_greyjoy), ancestor(alannys_harlaw, Y)]
# 1174 :: 13 - 00:00:00 (7602 nps)
#
# Query 30: [daughter(X, catelyn_stark), father(Y, X), child(bran_stark, Y)]
# 22 :: 8 - 00:00:00 (1770 nps)
#
# Query 31: [descendant(_EX0, unknown_mother_lannister)]
# 4 :: 3 - 00:00:00 (3919 nps)
#
# Query 32: [ancestor(alannys_harlaw, _EX0)]
# 3 :: 2 - 00:00:00 (3261 nps)
#
# Query 33: [parent(X, aerys_targaryen), father(X, rhaella_targaryen)]
# 5 :: 4 - 00:00:00 (3045 nps)
#
# Query 34: [mother_dragons(X, viserion), love(X, khal_drogo)]
# 3 :: 2 - 00:00:00 (18121 nps)
#
# Query 35: [daughter(X, _EX3)]
# 6 :: 3 - 00:00:00 (50279 nps)
#
# Query 36: [ancestor(luthor_tyrell, mace_tyrell)]
# 3 :: 2 - 00:00:00 (4286 nps)
#
# Query 37: [ancestor(_EX5, _EX1)]
# 3 :: 2 - 00:00:00 (2114 nps)
#
# Query 38: [ancestor(X, rhaenys_targaryen), son(Y, X), son(Y, aerys_targaryen)]
# 147 :: 10 - 00:00:00 (1701 nps)
#
# Query 39: [descendant(duncan_targaryen, unknown_mother_targaryen)]
# 4 :: 3 - 00:00:00 (4946 nps)
#
# Query 40: [descendant(aegon_targaryen, Y)]
# 4 :: 3 - 00:00:00 (30419 nps)
#
# Query 41: [mother(_EX1, sansa_stark)]
# 8 :: 3 - 00:00:00 (697 nps)
#
# Query 42: [descendant(Z, _EX4)]
# 4 :: 3 - 00:00:00 (3275 nps)
#
# Query 43: [son(X, alannys_harlaw), child(X, alannys_harlaw)]
# 29 :: 5 - 00:00:00 (1849 nps)
#
# Query 44: [ancestor(_EX1, _EX0)]
# 3 :: 2 - 00:00:00 (1355 nps)
#
# Query 45: [ancestor(unknown_mother_targaryen, X), parent(Y, X), ancestor(Y, aerys_targaryen)]
# 6 :: 5 - 00:00:00 (2240 nps)
#
# Query 46: [ancestor(_EX6, trystane_martell)]
# 3 :: 2 - 00:00:00 (4009 nps)
#
# Query 47: [rightful_heir_iron_throne_descedant_from_last_king_or_queen(_EX4)]
# 8 :: 3 - 00:00:00 (12212 nps)
#
# Query 48: [descendant(_EX5, Y)]
# 4 :: 3 - 00:00:00 (2848 nps)
#
# Query 49: [son(maron_greyjoy, Y)]
# 4 :: 3 - 00:00:00 (4055 nps)
#
# Query 50: [child(Z, X)]
# 3 :: 2 - 00:00:00 (2434 nps)
#
# Query 51: [descendant(Y, _EX4)]
# 4 :: 3 - 00:00:00 (3427 nps)
#
# Query 52: [daughter(X, oberyn_martell), descendant(X, unknown_mother_sand_1)]
# 78 :: 6 - 00:00:00 (1844 nps)
#
# Query 53: [descendant(rhaegar_targaryen, X), son(X, aegon_v_targaryen)]
# 7 :: 6 - 00:00:00 (3672 nps)
#
# Query 54: [mother(catelyn_stark, _EX1)]
# 4 :: 3 - 00:00:00 (2645 nps)
#
# Query 55: [child(_EX1, _EX3)]
# 3 :: 2 - 00:00:00 (2498 nps)
#
# Query 56: [son(stannis_baratheon, X)]
# 4 :: 3 - 00:00:00 (3872 nps)
#
# Query 57: [father(Y, X), ancestor(tytos_lannister, X), ancestor(Y, cersei_lannister)]
# 3095 :: 9 - 00:00:00 (3518 nps)
#
# Query 58: [who_betrayed_daenerys(X), betray(X, Y), betray(varys, Y)]
# 5 :: 4 - 00:00:00 (15550 nps)
#
# Query 59: [descendant(_EX0, tywin_lannister)]
# 4 :: 3 - 00:00:00 (3934 nps)
#
# Query 60: [who_is_the_breaker_of_chains(_EX3)]
# 4 :: 3 - 00:00:00 (29002 nps)
#
# Query 61: [son(maron_greyjoy, X), parent(X, Y), female(Y), son(theon_greyjoy, X)]
# 11 :: 8 - 00:00:00 (3766 nps)
#
# Query 62: [child(_EX2, _EX0)]
# 3 :: 2 - 00:00:00 (1029 nps)
#
# Query 63: [status(X, Y), father(X, Z), status(rickard_stark, Y), status(Z, Y)]
# 10 :: 6 - 00:00:00 (2415 nps)
#
# Query 64: [ancestor(X, Y), son(Z, X), who_is_the_breaker_of_chains(Y), ancestor(X, Z), descendant(viserys_targaryen, Z)]
# 7315 :: 15 - 00:00:01 (3889 nps)
#
# Query 65: [ancestor(_EX4, X)]
# 3 :: 2 - 00:00:00 (429 nps)
#
# Query 66: [descendant(lancel_lannister, Z)]
# 4 :: 3 - 00:00:00 (43060 nps)
#
# Query 67: [son(_EX0, _EX5)]
# 4 :: 3 - 00:00:00 (3242 nps)
#
# Query 68: [child(Z, _EX0)]
# 3 :: 2 - 00:00:00 (2122 nps)
#
# Query 69: [descendant(Y, X), father(X, balon_greyjoy), descendant(Y, Z), mother(Z, maron_greyjoy), descendant(yara_greyjoy, Z)]
# Query failed!!!
# 3074 :: 0 - 00:00:00 (10048 nps)
#
# Query 70: [who_loved_daenerys_and_was_corresponded(X), who_loved_daenerys(X), love(X, daenerys_targaryen)]
# 7 :: 6 - 00:00:00 (13481 nps)
#
# Query 71: [descendant(X, lewyn_martell)]
# 4 :: 3 - 00:00:00 (29220 nps)
#
# Query 72: [descendant(benjen_stark, _EX1)]
# 4 :: 3 - 00:00:00 (4686 nps)
#
# Query 73: [ancestor(_EX3, _EX6)]
# 3 :: 2 - 00:00:00 (1985 nps)
#
# Query 74: [son(X, rhaella_targaryen)]
# 32 :: 3 - 00:00:00 (1642 nps)
#
# Query 75: [male(X), son(X, kevan_lannister), status(X, dead)]
# 60 :: 5 - 00:00:00 (2777 nps)
#
# Query 76: [magic_ressurrected(X), creatures(X), status(X, alive)]
# 7 :: 4 - 00:00:00 (9687 nps)
#
# Query 77: [mother(elia_martell, X), ancestor(Y, X), descendant(daenerys_targaryen, Y), female(Y)]
# 160 :: 11 - 00:00:00 (9486 nps)
#
# Query 78: [descendant(_EX4, X)]
# 4 :: 3 - 00:00:00 (2299 nps)
#
# Query 79: [child(_EX4, Z)]
# 3 :: 2 - 00:00:00 (2363 nps)
#
# Query 80: [descendant(_EX4, Y)]
# 4 :: 3 - 00:00:00 (47959 nps)
#
# Query 81: [destroy(Y, X), destroy(Z, X), kill(euron_greyjoy, Y), child(Z, aerys_targaryen)]
# 9 :: 5 - 00:00:00 (9129 nps)
#
# Query 82: [descendant(trystane_martell, _EX3)]
# 4 :: 3 - 00:00:00 (4971 nps)
#
# Query 83: [who_betrayed_daenerys(varys)]
# 3 :: 2 - 00:00:00 (24308 nps)
#
# Query 84: [ancestor(X, Y), parent(X, rickon_stark), daughter(sansa_stark, X), son(Y, eddard_stark)]
# 18 :: 9 - 00:00:00 (3936 nps)
#
# Query 85: [ancestor(_EX2, _EX1)]
# 3 :: 2 - 00:00:00 (170 nps)
#
# Query 86: [descendant(Y, X), descendant(rhaenys_targaryen, X), ancestor(unknown_mother_targaryen, Y)]
# 1917 :: 12 - 00:00:00 (24440 nps)
#
# Query 87: [ancestor(_EX5, _EX1)]
# 3 :: 2 - 00:00:00 (35506 nps)
#
# Query 88: [father(Y, X), parent(cersei_lannister, X), descendant(Z, Y), descendant(Z, cersei_lannister)]
# 42 :: 10 - 00:00:00 (2642 nps)
#
# Query 89: [take_away(drogon, X), love(Y, X), who_loved_daenerys_and_was_corresponded(Y)]
# 6 :: 5 - 00:00:00 (14860 nps)
#
# Query 90: [mother(Z, rhaegar_targaryen)]
# 21 :: 3 - 00:00:00 (783 nps)
#
# Query 91: [father(tywin_lannister, jaime_lannister)]
# 4 :: 3 - 00:00:00 (2948 nps)
#
# Query 92: [descendant(loras_tyrell, X), descendant(margaery_tyrell, X)]
# 7 :: 6 - 00:00:00 (4594 nps)
#
# Query 93: [descendant(rhaegar_targaryen, _EX1)]
# 4 :: 3 - 00:00:00 (5122 nps)
#
# Query 94: [son(renly_baratheon, cassana_estermont)]
# 4 :: 3 - 00:00:00 (4068 nps)
#
# Query 95: [descendant(_EX0, alannys_harlaw)]
# 4 :: 3 - 00:00:00 (4088 nps)
#
# Query 96: [son(_EX4, _EX6)]
# 4 :: 3 - 00:00:00 (2292 nps)
#
# Query 97: [who_betrayed_each_other(jaime_lannister, Z)]
# 4 :: 3 - 00:00:00 (17702 nps)
#
# Query 98: [ancestor(_EX6, X)]
# 3 :: 2 - 00:00:00 (2065 nps)
#
# Query 99: [son(aeron_greyjoy, X), descendant(aeron_greyjoy, X), descendant(balon_greyjoy, X)]
# 10 :: 9 - 00:00:00 (5359 nps)
#
# Query 100: [father(jaime_lannister, X), son(X, jaime_lannister)]
# 7 :: 6 - 00:00:00 (5116 nps)
#
# std: 178.13 nodes/query
# 1 queries failed
# Time to run all queries: 3.9331447389999923
# using cuda device
# UNITY: ming
# 	Embedding Model: rKB_model.pth
# 	Scoring Model: uni_mr_model.pt
#
# 	Control: mingoal
# 	Rule Eval: Max Rule
# Learned Embedding: Network using cuda
# /opt/tljh/user/envs/cse327python311/lib/python3.11/site-packages/torch/nn/modules/lazy.py:180: UserWarning: Lazy modules are a new feature under heavy development so changes to the API or functionality can happen at any moment.
#   warnings.warn('Lazy modules are a new feature under heavy development '
# Query 1: [mother(X, kevan_lannister), parent(X, tywin_lannister)]
# 5 :: 4 - 00:00:00 (7 nps)
#
# Query 2: [male(X), kill(arya_stark, X), night_walkers_king(X), who_brought_the_winter(X), night_walker(X)]
# 8 :: 7 - 00:00:00 (32 nps)
#
# Query 3: [ancestor(Z, _EX1)]
# 3 :: 2 - 00:00:00 (5 nps)
#
# Query 4: [ancestor(lewyn_martell, _EX5)]
# 3 :: 2 - 00:00:00 (93 nps)
#
# Query 5: [descendant(X, _EX6)]
# 8 :: 5 - 00:00:01 (5 nps)
#
# Query 6: [descendant(_EX5, _EX6)]
# 4 :: 3 - 00:00:00 (7 nps)
#
# Query 7: [father(_EX2, maron_greyjoy)]
# 4 :: 3 - 00:00:00 (20 nps)
#
# Query 8: [child(X, rhaella_targaryen), descendant(X, rhaella_targaryen), descendant(X, Y), descendant(rhaella_targaryen, Y)]
# 587 :: 13 - 00:00:17 (33 nps)
#
# Query 9: [parent(elia_martell, X), male(X), child(X, elia_martell), ancestor(rhaegar_targaryen, X)]
# 7 :: 6 - 00:00:00 (32 nps)
#
# Query 10: [mother_dragons(daenerys_targaryen, X), status(X, Y), status(sansa_stark, Y), kill(night_king, X)]
# 5 :: 4 - 00:00:00 (15 nps)
#
# Query 11: [descendant(_EX0, Y)]
# 4 :: 3 - 00:00:00 (9 nps)
#
# Query 12: [ancestor(cassana_estermont, _EX4)]
# 3 :: 2 - 00:00:00 (124 nps)
#
# Query 13: [descendant(lancel_lannister, Z)]
# 4 :: 3 - 00:00:00 (211 nps)
#
# Query 14: [ancestor(_EX1, jon_snow)]
# 3 :: 2 - 00:00:00 (143 nps)
#
# Query 15: [male(X), child(X, Y), son(X, unknown_mother_targaryen), parent(Y, aerys_targaryen)]
# 14 :: 6 - 00:00:00 (115 nps)
#
# Query 16: [ancestor(_EX0, tommen_lannister)]
# 3 :: 2 - 00:00:00 (144 nps)
#
# Query 17: [ancestor(_EX0, lyanna_stark)]
# 3 :: 2 - 00:00:00 (150 nps)
#
# Query 18: [daughter(_EX2, _EX3)]
# 5 :: 3 - 00:00:00 (8 nps)
#
# Query 19: [child(rhaella_targaryen, _EX2)]
# 3 :: 2 - 00:00:00 (167 nps)
#
# Query 20: [rightful_heir_iron_throne_descedant_from_last_king_or_queen(_EX5)]
# 4 :: 3 - 00:00:00 (40 nps)
#
# Query 21: [parent(Y, X), descendant(sansa_stark, X), ancestor(Y, rickon_stark)]
# Query failed!!!
# 1000000 :: 0 - 00:02:17 (7278 nps)
#
# Query 22: [descendant(jaime_lannister, _EX6)]
# 4 :: 3 - 00:00:00 (124 nps)
#
# Query 23: [descendant(_EX4, Y)]
# 4 :: 3 - 00:00:00 (7 nps)
#
# Query 24: [status(X, Z), father(Y, X), child(X, Y), status(lewyn_martell, Z), ancestor(Y, X)]
# 8 :: 7 - 00:00:01 (4 nps)
#
# Query 25: [daughter(sansa_stark, _EX1)]
# 4 :: 3 - 00:00:00 (177 nps)
#
# Query 26: [ancestor(_EX6, _EX3)]
# 3 :: 2 - 00:00:00 (6 nps)
#
# Query 27: [descendant(_EX6, X)]
# Query failed!!!
# 1000000 :: 0 - 00:16:02 (1038 nps)
#
# Query 28: [descendant(jon_snow, X)]
# 4 :: 3 - 00:00:00 (107 nps)
#
# Query 29: [descendant(Y, X), mother(X, Z), male(Y), child(Z, unknown_father_greyjoy), ancestor(alannys_harlaw, Y)]
# 39 :: 13 - 00:00:00 (65 nps)
#
# Query 30: [daughter(X, catelyn_stark), father(Y, X), child(bran_stark, Y)]
# 28 :: 8 - 00:00:00 (114 nps)
#
# Query 31: [descendant(_EX0, unknown_mother_lannister)]
# 6 :: 5 - 00:00:00 (13 nps)
#
# Query 32: [ancestor(alannys_harlaw, _EX0)]
# 3 :: 2 - 00:00:00 (116 nps)
#
# Query 33: [parent(X, aerys_targaryen), father(X, rhaella_targaryen)]
# 8 :: 4 - 00:00:00 (195 nps)
#
# Query 34: [mother_dragons(X, viserion), love(X, khal_drogo)]
# 3 :: 2 - 00:00:00 (262 nps)
#
# Query 35: [daughter(X, _EX3)]
# 5 :: 3 - 00:00:00 (10 nps)
#
# Query 36: [ancestor(luthor_tyrell, mace_tyrell)]
# 3 :: 2 - 00:00:00 (182 nps)
#
# Query 37: [ancestor(_EX5, _EX1)]
# 3 :: 2 - 00:00:00 (7 nps)
#
# Query 38: [ancestor(X, rhaenys_targaryen), son(Y, X), son(Y, aerys_targaryen)]
# 46 :: 7 - 00:00:01 (32 nps)
#
# Query 39: [descendant(duncan_targaryen, unknown_mother_targaryen)]
# 286345 :: 3 - 00:00:27 (10534 nps)
#
# Query 40: [descendant(aegon_targaryen, Y)]
# 4 :: 3 - 00:00:00 (143 nps)
#
# Query 41: [mother(_EX1, sansa_stark)]
# 4 :: 3 - 00:00:00 (43 nps)
#
# Query 42: [descendant(Z, _EX4)]
# 4 :: 3 - 00:00:00 (10 nps)
#
# Query 43: [son(X, alannys_harlaw), child(X, alannys_harlaw)]
# 6 :: 5 - 00:00:00 (114 nps)
#
# Query 44: [ancestor(_EX1, _EX0)]
# 3 :: 2 - 00:00:00 (6 nps)
#
# Query 45: [ancestor(unknown_mother_targaryen, X), parent(Y, X), ancestor(Y, aerys_targaryen)]
# 6 :: 5 - 00:00:00 (12 nps)
#
# Query 46: [ancestor(_EX6, trystane_martell)]
# 3 :: 2 - 00:00:00 (213 nps)
#
# Query 47: [rightful_heir_iron_throne_descedant_from_last_king_or_queen(_EX4)]
# 4 :: 3 - 00:00:00 (71 nps)
#
# Query 48: [descendant(_EX5, Y)]
# 4 :: 3 - 00:00:00 (13 nps)
#
# Query 49: [son(maron_greyjoy, Y)]
# 4 :: 3 - 00:00:00 (72 nps)
#
# Query 50: [child(Z, X)]
# 3 :: 2 - 00:00:00 (10 nps)
#
# Query 51: [descendant(Y, _EX4)]
# 4 :: 3 - 00:00:00 (9 nps)
#
# Query 52: [daughter(X, oberyn_martell), descendant(X, unknown_mother_sand_1)]
# 7 :: 6 - 00:00:00 (117 nps)
#
# Query 53: [descendant(rhaegar_targaryen, X), son(X, aegon_v_targaryen)]
# 63772 :: 6 - 00:00:04 (13837 nps)
#
# Query 54: [mother(catelyn_stark, _EX1)]
# 4 :: 3 - 00:00:00 (81 nps)
#
# Query 55: [child(_EX1, _EX3)]
# 3 :: 2 - 00:00:00 (8 nps)
#
# Query 56: [son(stannis_baratheon, X)]
# 4 :: 3 - 00:00:00 (195 nps)
#
# Query 57: [father(Y, X), ancestor(tytos_lannister, X), ancestor(Y, cersei_lannister)]
# 20 :: 9 - 00:00:00 (99 nps)
#
# Query 58: [who_betrayed_daenerys(X), betray(X, Y), betray(varys, Y)]
# 4 :: 3 - 00:00:00 (44 nps)
#
# Query 59: [descendant(_EX0, tywin_lannister)]
# 4 :: 3 - 00:00:00 (143 nps)
#
# Query 60: [who_is_the_breaker_of_chains(_EX3)]
# 4 :: 3 - 00:00:00 (185 nps)
#
# Query 61: [son(maron_greyjoy, X), parent(X, Y), female(Y), son(theon_greyjoy, X)]
# 273 :: 8 - 00:00:01 (202 nps)
#
# Query 62: [child(_EX2, _EX0)]
# 3 :: 2 - 00:00:00 (8 nps)
#
# Query 63: [status(X, Y), father(X, Z), status(rickard_stark, Y), status(Z, Y)]
# 7 :: 6 - 00:00:01 (4 nps)
#
# Query 64: [ancestor(X, Y), son(Z, X), who_is_the_breaker_of_chains(Y), ancestor(X, Z), descendant(viserys_targaryen, Z)]
# 1261 :: 14 - 00:00:18 (67 nps)
#
# Query 65: [ancestor(_EX4, X)]
# 3 :: 2 - 00:00:00 (10 nps)
#
# Query 66: [descendant(lancel_lannister, Z)]
# 4 :: 3 - 00:00:00 (223 nps)
#
# Query 67: [son(_EX0, _EX5)]
# 5 :: 3 - 00:00:00 (12 nps)
#
# Query 68: [child(Z, _EX0)]
# 3 :: 2 - 00:00:00 (9 nps)
#
# Query 69: [descendant(Y, X), father(X, balon_greyjoy), descendant(Y, Z), mother(Z, maron_greyjoy), descendant(yara_greyjoy, Z)]
# Query failed!!!
# 4363 :: 0 - 00:00:56 (77 nps)
#
# Query 70: [who_loved_daenerys_and_was_corresponded(X), who_loved_daenerys(X), love(X, daenerys_targaryen)]
# 5 :: 4 - 00:00:00 (63 nps)
#
# Query 71: [descendant(X, lewyn_martell)]
# 4 :: 3 - 00:00:00 (171 nps)
#
# Query 72: [descendant(benjen_stark, _EX1)]
# 4 :: 3 - 00:00:00 (223 nps)
#
# Query 73: [ancestor(_EX3, _EX6)]
# Query failed!!!
# 1000000 :: 0 - 00:17:08 (972 nps)
#
# Query 74: [son(X, rhaella_targaryen)]
# 4 :: 3 - 00:00:00 (272 nps)
#
# Query 75: [male(X), son(X, kevan_lannister), status(X, dead)]
# 5 :: 4 - 00:00:00 (21 nps)
#
# Query 76: [magic_ressurrected(X), creatures(X), status(X, alive)]
# 9 :: 4 - 00:00:00 (204 nps)
#
# Query 77: [mother(elia_martell, X), ancestor(Y, X), descendant(daenerys_targaryen, Y), female(Y)]
# 1116 :: 11 - 00:00:03 (341 nps)
#
# Query 78: [descendant(_EX4, X)]
# 4 :: 3 - 00:00:00 (30 nps)
#
# Query 79: [child(_EX4, Z)]
# 3 :: 2 - 00:00:00 (24 nps)
#
# Query 80: [descendant(_EX4, Y)]
# 4 :: 3 - 00:00:00 (19659 nps)
#
# Query 81: [destroy(Y, X), destroy(Z, X), kill(euron_greyjoy, Y), child(Z, aerys_targaryen)]
# 15 :: 5 - 00:00:00 (437 nps)
#
# Query 82: [descendant(trystane_martell, _EX3)]
# 4 :: 3 - 00:00:00 (452 nps)
#
# Query 83: [who_betrayed_daenerys(varys)]
# 3 :: 2 - 00:00:00 (1081 nps)
#
# Query 84: [ancestor(X, Y), parent(X, rickon_stark), daughter(sansa_stark, X), son(Y, eddard_stark)]
# 16 :: 9 - 00:00:00 (83 nps)
#
# Query 85: [ancestor(_EX2, _EX1)]
# 3 :: 2 - 00:00:00 (23 nps)
#
# Query 86: [descendant(Y, X), descendant(rhaenys_targaryen, X), ancestor(unknown_mother_targaryen, Y)]
# 34 :: 12 - 00:00:00 (396 nps)
#
# Query 87: [ancestor(_EX5, _EX1)]
# 3 :: 2 - 00:00:00 (18956 nps)
#
# Query 88: [father(Y, X), parent(cersei_lannister, X), descendant(Z, Y), descendant(Z, cersei_lannister)]
# 14 :: 10 - 00:00:00 (44 nps)
#
# Query 89: [take_away(drogon, X), love(Y, X), who_loved_daenerys_and_was_corresponded(Y)]
# 6 :: 4 - 00:00:00 (111 nps)
#
# Query 90: [mother(Z, rhaegar_targaryen)]
#  [-------------------------] 0.0% to max depth (384 nps)

# %% [markdown]
# The results suggest only minor improvements for the gameofthrones KB: on average 3.75 vs. 4.39 node per query when I ran it. You may get different results due to the randomization of training and random selection of test queries. Larger, more complex KBs can see much larger improvements, sometimes an order of magnitude or more.
#
# The code below shows the first 10 lines of each query result file. A given line has:
# * query sequence number
# * configuration name
# * number of nodes explored
# * depth of solution (0 if no solution found)
# * did the system find a solution (true/false)
# * time in seconds
#
# You can import these files into a spreadsheet in order to create plots or summary statistics.

# %%
# !head std-45-106-2-50.csv
# !head ming-45-106-2-50.csv
# Out:
# query,std reasoner,std nodes explored,std min depth,success,time
# 1,std,32,4,True,0.02009496600000027
# 2,std,33,7,True,0.0019755799999998658
# 3,std,3,2,True,0.0015283219999995268
# 4,std,3,2,True,0.0009759840000000963
# 5,std,4,3,True,0.0011998389999998693
# 6,std,4,3,True,0.0012074389999998658
# 7,std,8,3,True,0.0036835729999999955
# 8,std,59,13,True,0.017347399000000152
# 9,std,7,6,True,0.002562507999999575
# query,ming reasoner,ming nodes explored,ming min depth,success,time
# 1,ming,5,4,True,0.658156786000001
# 2,ming,8,7,True,0.24486948199999858
# 3,ming,3,2,True,0.5300766029999995
# 4,ming,3,2,True,0.032032372999999836
# 5,ming,8,5,True,1.560161707999999
# 6,ming,4,3,True,0.5252669090000008
# 7,ming,4,3,True,0.196291102
# 8,ming,587,13,True,17.392180805
# 9,ming,7,6,True,0.21597710900000067

# %% [markdown]
# STEP 5:
# Use the code to generate three random KBs of sizes 200, 300, and 400. To keep from
# overwriting important files, it is recommended that you create each in its own subdirectory.
# For example, if you want to put the 400 statement KB in a directory named size400:
# cd size400
# python ..\kbencoder.py --generate_kb --num_rules 400 --new_vocab --save_vocab

# %%
# %cd size300
# !python ../kbencoder.py --generate_kb --num_rules 300 --new_vocab --save_vocab
# Out:
# /data/users/jupyter-zmf227/cse327-p4-files/size300
# Classes: 100000000000.0
# Max arity: 5
# KB generated (300)

# %% [markdown]
# STEP 6:
# For each random KB, train the embedding and scoring models and then compare reasoning
# using the scoring model to the standard reasoner.

# %%
# prepare and train using kbencoder
# !python ../kbencoder.py --kb_path randomKB.txt --train_unification_model
# Out:
# Using cuda device
# Uni model embed size: 50
#  [████████████████████] 3500/3500 Anchors generated
#  [████████████████████] 70000/70000 Triplets generated
#  [█████---------------] 18230/70000 Triplet encodings
# IOPub data rate exceeded.
# The Jupyter server will temporarily stop sending output
# to the client in order to avoid crashing it.
# To change this limit, set the config variable
# `--ServerApp.iopub_data_rate_limit`.
#
# Current values:
# ServerApp.iopub_data_rate_limit=1000000.0 (bytes/sec)
# ServerApp.rate_limit_window=3.0 (secs)
#  [███████████---------] 39557/70000 Triplet encodings
# IOPub data rate exceeded.
# The Jupyter server will temporarily stop sending output
# to the client in order to avoid crashing it.
# To change this limit, set the config variable
# `--ServerApp.iopub_data_rate_limit`.
#
# Current values:
# ServerApp.iopub_data_rate_limit=1000000.0 (bytes/sec)
# ServerApp.rate_limit_window=3.0 (secs)
#  [██████████████████--] 64173/70000 Triplet encodings
# IOPub data rate exceeded.
# The Jupyter server will temporarily stop sending output
# to the client in order to avoid crashing it.
# To change this limit, set the config variable
# `--ServerApp.iopub_data_rate_limit`.
#
# Current values:
# ServerApp.iopub_data_rate_limit=1000000.0 (bytes/sec)
# ServerApp.rate_limit_window=3.0 (secs)
# Early stopping triggered-------------] 16.2% Epoch | [Epoch 82/500, Training Loss: 0.2868, Validation Loss: 0.6358]
# Saved model.
# Saved plot.
# unification model generated

# %% [markdown]
# IGNORE ALL BELOW:

# %%
# will read randomKB.txt and generate mr_train_examples.csv and test_queries.txt into the size300 folder
# !python ../gen_queries.py --kb_path randomKB.txt
# Out:
# Traceback (most recent call last):
#   File "/data/users/jupyter-zmf227/cse327-p4-files/size300/../gen_queries.py", line 62, in <module>
#     generate_variable_combinations('lubm_query_from_q14.txt')
#   File "/data/users/jupyter-zmf227/cse327-p4-files/size300/../gen_queries.py", line 12, in generate_variable_combinations
#     facts = parse_KB_file(input_file)
#             ^^^^^^^^^^^^^^^^^^^^^^^^^
#   File "/data/users/jupyter-zmf227/cse327-p4-files/kbparser.py", line 74, in parse_KB_file
#     with open(file_path, mode='r') as f:
#          ^^^^^^^^^^^^^^^^^^^^^^^^^
# FileNotFoundError: [Errno 2] No such file or directory: 'lubm_query_from_q14.txt'

# %%
# !python ../nnreasoner.py --kb_path randomKB.txt --embed_type unification
# Out:
# usage: nnreasoner.py [-h] [-t TRAINING_FILE] [-s SAVE_MODEL]
#                      [--num_epochs NUM_EPOCHS]
#                      [--embed_type {unification,autoencoder,chainbased,termwalk}]
#                      [--vocab_file VOCAB_FILE] [-e EMBED_SIZE]
#                      [--embed_model_path EMBED_MODEL_PATH]
# nnreasoner.py: error: unrecognized arguments: --kb_path randomKB.txt

# %%
# train the scoring model (nnreasoner)
# !python ../nnreasoner.py --embed_type unification
# Out:
# States from vocab: vocab
# Num predicates: 10
# Max arity: 5
# Num constants: 100
# Num variables: 10
#
# Training unification
# Embed size: 50
# Reading examples from mr_train_examples.csv
# Traceback (most recent call last):
#   File "/data/users/jupyter-zmf227/cse327-p4-files/size300/../nnreasoner.py", line 354, in <module>
#     train_reasoning_model(
#   File "/data/users/jupyter-zmf227/cse327-p4-files/size300/../nnreasoner.py", line 127, in train_reasoning_model
#     with open(training_file, mode="r") as f:
#          ^^^^^^^^^^^^^^^^^^^^^^^^^^^^^
# FileNotFoundError: [Errno 2] No such file or directory: 'mr_train_examples.csv'

# %%
# evaluate and compare
# !python ../evaluate.py --kb_path randomKB.txt -s
# !python ../evaluate.py --kb_path randomKB.txt -u
# Out:
# usage: evaluate.py [-h] [--kb KB] [--qfile QFILE] [--vocab_file VOCAB_FILE]
#                    [-e EMBED_SIZE] [-s] [-u]
#                    [--embed_model_path EMBED_MODEL_PATH]
#                    [--scoring_model_path SCORING_MODEL_PATH] [-a]
#                    [--auto_model_path AUTO_MODEL_PATH]
#                    [--auto_guidance_model_path AUTO_GUIDANCE_MODEL_PATH] [-t]
#                    [--termwalk_guidance_model_path TERMWALK_GUIDANCE_MODEL_PATH]
#                    [-c]
#                    [--chainbased_guidance_model_path CHAINBASED_GUIDANCE_MODEL_PATH]
#                    [--config_name CONFIG_NAME] [--use_min_score]
#                    [--control {allgoals,mingoal,maxgoal}] [--trace]
#                    [--explain]
# evaluate.py: error: unrecognized arguments: --kb_path randomKB.txt
# usage: evaluate.py [-h] [--kb KB] [--qfile QFILE] [--vocab_file VOCAB_FILE]
#                    [-e EMBED_SIZE] [-s] [-u]
#                    [--embed_model_path EMBED_MODEL_PATH]
#                    [--scoring_model_path SCORING_MODEL_PATH] [-a]
#                    [--auto_model_path AUTO_MODEL_PATH]
#                    [--auto_guidance_model_path AUTO_GUIDANCE_MODEL_PATH] [-t]
#                    [--termwalk_guidance_model_path TERMWALK_GUIDANCE_MODEL_PATH]
#                    [-c]
#                    [--chainbased_guidance_model_path CHAINBASED_GUIDANCE_MODEL_PATH]
#                    [--config_name CONFIG_NAME] [--use_min_score]
#                    [--control {allgoals,mingoal,maxgoal}] [--trace]
#                    [--explain]
# evaluate.py: error: unrecognized arguments: --kb_path randomKB.txt

# %%
# %cd ..
# Out:
# /data/users/jupyter-zmf227/cse327-p4-files

# %%
# %cd size300
# Out:
# /data/users/jupyter-zmf227/cse327-p4-files/size300
